# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_excel('xinloupan.xls')

# %%
#价格分析
df.price[df.price == '价格待定'] = np.nan

# %%
df.price = df.price.astype('float')

# %%
df_1 = df[df.area.notna()]

# %%
df_1[df_1.price > 30000]
# Out:
#         xiaoqu    price  total         area    house_type  \
# 4         望江名门  45000.0  1700万        3室(2)  建面 320~443m²
# 9         恒大广场  32000.0   660万        5室(1)      建面 219m²
# 200       兰博中心  48000.0  1104万        3室(1)      建面 230m²
# 213       兰博中心  48000.0  1104万        3室(1)      建面 230m²
# 319       成功悦都  35000.0      0  3室(4)/2室(1)    建面 67~90m²
# 357      成都文儒德  42000.0   837万  5室(2)/4室(1)  建面 185~213m²
# 376  成都棕榈泉国际中心  32000.0   285万  3室(2)/2室(1)   建面 89~129m²
#
#                           location
# 4                锦江/莲花/三官堂街与龙舟路交汇处
# 9         青羊/太升路/提督街99号（近四川国际大厦E区）
# 200  青羊/人民公园/成都市锦江区新光华街7号航天科技大厦19楼
# 213  青羊/人民公园/成都市锦江区新光华街7号航天科技大厦19楼
# 319      成华/八里小区/双建路建行正对面（原双建路79号）
# 357    高新/金融城/近慈路66号（石室中学后门石羊派出所旁）
# 376              高新/新会展/天府大道中段199号

# %%
df_1.price.hist(bins=100)

# %%
np.array(df_1.price.dropna()/10000)
# Out:
# array([2.600e+00, 1.900e+00, 2.000e+00, 1.600e+00, 4.500e+00, 1.250e+00,
#        5.100e-01, 1.950e+00, 3.200e+00, 3.000e+00, 2.500e+00, 2.400e+00,
#        2.300e+00, 1.600e+00, 3.000e-02, 1.150e+00, 1.300e-01, 7.680e-02,
#        1.100e+00, 1.600e+00, 9.500e-03, 1.400e+00, 1.200e+00, 9.800e-01,
#        7.500e-02, 1.250e+00, 1.100e+00, 8.000e-03, 7.500e-01, 5.500e-01,
#        1.200e+00, 8.000e-02, 1.200e+00, 1.400e+00, 8.520e-01, 1.100e+00,
#        2.300e+00, 8.520e-01, 1.100e+00, 2.300e+00, 2.300e+00, 3.000e-02,
#        9.850e-01, 8.000e-01, 2.000e+00, 2.300e+00, 1.700e+00, 9.600e-01,
#        9.850e-01, 6.100e-01, 1.350e+00, 9.500e-01, 1.350e+00, 2.000e-02,
#        9.500e-01, 1.630e+00, 2.850e+00, 6.800e-01, 7.000e-02, 2.850e+00,
#        6.800e-01, 1.900e+00, 1.500e+00, 4.800e+00, 8.000e-01, 1.900e+00,
#        1.600e+00, 4.800e+00, 8.000e-01, 9.300e-01, 9.300e-01, 1.700e+00,
#        5.900e-01, 1.430e+00, 1.000e+00, 1.000e+00, 2.500e+00, 8.400e-01,
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.figure(figsize=(10,5)) 

mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei']#指定默认字体  
mpl.rcParams['axes.unicode_minus'] = False #解决保存图像是负号'-'显示为方块的问题 
sns.set_context("talk")
mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei']#指定默认字体  
mpl.rcParams['axes.unicode_minus'] =False #
sns.set(style="white", palette="muted", color_codes=True)
rs = df_1.price
# Plot a historgram and kernel density estimate
sns.distplot(np.array(df_1.price.dropna()/10000), color="m")
plt.title('The Distribution plot of Chengdu New Housing Price')
plt.xlabel('price/Ten thousand')
plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
#from collections import Counter

# %%
area_list = list(df.area.dropna())

# %%
a_ = []
for i in area_list:
    tem = i.split('/')
    for j in tem:
        a_.append(j)

# %%
for i,j in enumerate(a_):
    a_[i] = j[:2]

# %%
area = pd.Series(Counter(a_))

# %%
area_ = area/area.sum()

# %%
list(area.values)
# Out:
# [2, 101, 87, 180, 114, 31, 9, 3, 2]

# %%
import matplotlib.pyplot as plt  

# 设置绘图的主题风格（不妨使用R中的ggplot分隔）  
plt.style.use('ggplot')  
plt.figure(figsize=(10,10)) 
# 构造数据  
x = [2, 101, 87, 180, 114, 31, 14]
y = ['0室', '1室', '2室', '3室', '4室', '5室', '6~8室']
explode = [0,0,0,0.1,0,0,0]  # 用于突出显示大专学历人群  
colors=['#9999ff','#ff9999','#7777aa','#2442aa','#dd5555'] # 自定义颜色  

# 中文乱码和坐标轴负号的处理  
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']  
plt.rcParams['axes.unicode_minus'] = False  

# 将横、纵坐标轴标准化处理，保证饼图是一个正圆，否则为椭圆  
plt.axes(aspect='equal')  

# 控制x轴和y轴的范围  
plt.xlim(0,4)  
plt.ylim(0,4)  

# 绘制饼图  
plt.pie(x = x, # 绘图数据  
    explode=explode, # 突出显示大专人群  
    labels=y, # 添加教育水平标签  
    colors=colors, # 设置饼图的自定义填充色  
    autopct='%.1f%%', # 设置百分比的格式，这里保留一位小数  
    pctdistance=0.8,  # 设置百分比标签与圆心的距离  
    labeldistance = 1.15, # 设置教育水平标签与圆心的距离  
    startangle = 180, # 设置饼图的初始角度  
    radius = 1.5, # 设置饼图的半径  
    counterclock = False, # 是否逆时针，这里设置为顺时针方向  
    wedgeprops = {'linewidth': 1.5, 'edgecolor':'green'},# 设置饼图内外边界的属性值  
    textprops = {'fontsize':12, 'color':'k'}, # 设置文本标签的属性值  
    center = (1.8,1.8), # 设置饼图的原点  
    frame = 1 )# 是否显示饼图的图框，这里设置显示  

# 删除x轴和y轴的刻度  
plt.xticks(())  
plt.yticks(())  
# 添加图标题  
plt.title('成都市新房户型占比')  

# 显示图形  
plt.show()

# %%
df_1
# Out:
#          xiaoqu    price  total         area    house_type  \
# 0        恒大望江华府  26000.0   468万        4室(1)      建面 191m²
# 1          银海中心  19000.0    96万  2室(1)/1室(2)   建面 50~101m²
# 2          时代晶座  20000.0   100万  2室(1)/1室(5)    建面 49~76m²
# 3       佳年华广场二期  16000.0    60万  2室(1)/1室(2)    建面 35~41m²
# 4          望江名门  45000.0  1700万        3室(2)  建面 320~443m²
# 5          金科中心  12500.0    60万        2室(1)       建面 48m²
# 7           杜鹃城   5100.0    67万  3室(1)/2室(2)   建面 80~131m²
# 8       美洲花园棕榈湾  19500.0   158万        4室(2)   建面 90~105m²
# 9          恒大广场  32000.0   660万        5室(1)      建面 219m²
# 10      九龙仓擎天半岛  30000.0   720万        3室(1)      建面 240m²
# 11       润富国际花园  25000.0   140万        1室(1)       建面 51m²
# 12         星汇广场  24000.0   362万  3室(1)/1室(1)  建面 145~173m²
# 13          香悦城  23000.0    96万        2室(1)       建面 42m²
# 14        新鸿基悦城  16000.0      0        4室(1)      建面 272m²
# 15      阿玛尼艺术公寓    300.0   930万  4室(1)/3室(1)  建面 160~192m²
# ...

# %%
import re
com_ = re.compile('(.+)/')
location = df_1.location.apply(lambda x:com_.findall(com_.findall(x)[0])[0])

# %%
loc_ = pd.Series(Counter(location)).sort_values(ascending = False)

# %%
loc_ = pd.DataFrame(loc_)

# %%
loc_.columns = ['location']

# %%
loc_['dd'] = loc_.index

# %%
loc_
# Out:
#         location      dd
# 武侯            40      武侯
# 新都            35      新都
# 高新            33      高新
# 成华            30      成华
# 天府新区          24    天府新区
# 郫都            19      郫都
# 龙泉驿           19     龙泉驿
# 双流            18      双流
# 锦江            17      锦江
# 温江            15      温江
# 金堂            12      金堂
# 天府新区南区         9  天府新区南区
# 青白江            8     青白江
# 大邑             8      大邑
# 青羊             8      青羊
# 金牛             7      金牛
# 仁寿县            7     仁寿县
# 新津             7      新津
# 都江堰            7     都江堰
# 东坡区            6     东坡区
# 崇州             6      崇州
# 峨眉山市           3    峨眉山市
# 高新西            2     高新西
# 彭州             2      彭州
# 广汉市            1     广汉市
# 邛崃             1      邛崃

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['simhei']
mpl.rcParams['font.serif'] = ['simhei']

sns.set_style("darkgrid",{"font.sans-serif":['simhei','Droid Sans Fallback']})
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 6))

# Load the example car crash dataset
crashes = loc_#sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
#sns.barplot(x="location", y="abbrev", data=crashes,
#            label="Total", color="b")
sns.barplot(x="location", y="dd", data=crashes,
            label="Total", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 45), ylabel="",
       xlabel="个数")
sns.despine(left=True, bottom=True)
